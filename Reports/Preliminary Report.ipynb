# %% [markdown]
# # Voting Complexity:

# %% [markdown]
# #### Jared Briskman

# %% [markdown]
# ## Abstract
#
# This project aims to simulate elections as an agent based phenomenon, with a distribution of voters existing in some discrete, multi-dimensional opinion space.
# Candidates exist as points in the space, and voters are (At least initially) are assumed to be normally distributed around a given center.
# Simulating multiple voting algorithms (Plurality, Approval, Condorcet, Borda, IRV) can be achieved by assuming that people's candidate preferences go in order of Euclidean distance.
#
# Using these simulations, limiting cases of Arrow's theorem (That no election system can satisfy all 5 fair election criterion) can be demonstrated, and visualizations of voter space can be generated.
#
# Further expansion can be done by simulating more voting systems, and moving to a higher dimensional space.
# Interesting data may also result from sweeping candidates across the space, and analyzing the results.

# %% [markdown]
# ## Lit Review
#
# http://zesty.ca/voting/sim/
# An explanation of sprint 1 target and MVP.
#
#
# https://www.jstor.org/stable/1914083?seq=12#page_scan_tab_contents
# Arrow's theorem proof.

# %% [markdown]
# ## Target
#
# First punchline graphs as the same ones from zesty above. These can be analyzed as how different voting systems affect candidate's chances of winning under different political orientations.
# E.G. Here, under IRV, one can see candidate 3 has an "M" shaped winning space.
# This is non-monotonic leading to very interesting results: more approval for the candidate could cause worse results, and less approval could cause the candidate to win.
#
# Another punchline graph could result from changing the delta between two candidates: E.G keeping one stable and sweeping the other, then plotting overall odds of winning.

# %% [markdown]
# ![Chart](../Code/Political_chart.svg.png)

# %% [markdown]
# ![Target](http://zesty.ca/voting/sim/93,49_79,42_27,45_plu.png)

# %% [markdown]
# ## Results
#
# Plurality voting, election simulation and visualization are all working. This allows replication some components of the targeted experiments above, E.G.
#
# ![demo2](../Code/demo2.png)
#
# Here, we can see how a moderate candidate (in fact completely centered) can be squeezed out by semi-moderates on either side. It is interesting to alse see how the center candidate can appeal to two very extreme opposites in opinion, in the top left and bottom right, created due to the symmetries in the space.
#
# To really perform an actual experiment, a second voting method will need to be fully implemented. Instant runoff voting is almost working at this stage, and will be in a day or two. With IRV, nonmonotonic voting conditions can be demonstrated, which is actually meaningful when compared to the same election run under Plurality voting.
#
# These graphs are generated by specifying an arbitrary number of candidates, and $\sigma$ and a range of $\mu$'s for the population distribution. Then a space of elections is run, and the winner at each point is displayed.
# E.G.
#
# ![demo1](../Code/demo1.png)

# %% [markdown]
# ## Learning Goals
#
# ### Original statement
# Trying to find the self organizing criticality inherent to election systems. (I do believe it is there, it just may be a task to tease it out)
# Data visualization in python, along with high order complexity algorithm design for voting systems.
# Technical writing in an easy to understand fashion: I want to be able to clearly and succinctly share my methods and results.
#
# ### Thoughts thus far
# I've met the algorithm design and data visualization goals I had, which came in the form of implementing elections and reading much more matplotlib documentation than I needed to in order to generate the graphs seen above. Also, practicing good object oriented structure is nice, and I see myself echoing a lot of Allen's style in my own code.
#
# I'm confident the technical writing component will get there when I have things to really write about in the next sprint.
#
# The first goal is really the most unsure, and also the one I've spent the most time thinking about. I'm not sure of what conditions to create and transformation to apply to the data to demonstrate self organized criticality. I think plotting the different rounds of IRV with multiple candidates may be a good angle, will play around with over break.

# %% [markdown]
# ## Disclaimer:
# This is much more of a status report than a premilinary version of final stuff, I'm ~85% of the way to being able to do really interesting things with my model, but not quite there yet. Gonna put in more work in the next few days to get there.
